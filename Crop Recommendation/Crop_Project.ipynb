# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pickle

# %%
df1=pd.read_csv('/content/Crop_recommendation.csv')
df2=pd.read_csv('/content/Crop_recommendation df1.csv')

# %%
df1
# Out:
#       Nitrogen  Phosphorus  Potassium   ph  Rainfall  Temperature       Crop  \
# 0           75          50        100  6.5      1000           20  Sugarcane
# 1           80          50        100  6.5      1000           20  Sugarcane
# 2           85          50        100  6.5      1000           20  Sugarcane
# 3           90          50        100  6.5      1000           20  Sugarcane
# 4           95          50        100  6.5      1000           20  Sugarcane
# ...        ...         ...        ...  ...       ...          ...        ...
# 4508       130          80        150  7.0      1400           30  Sugarcane
# 4509       135          80        150  7.0      1400           30  Sugarcane
# 4510       140          80        150  7.0      1400           30  Sugarcane
# 4511       145          80        150  7.0      1400           30  Sugarcane
# 4512       150          80        150  7.0      1400           30  Sugarcane
#
# ...

# %%
df1=df1.drop(columns=['Fertilizer','Link'])

# %%
df1
# Out:
#       Nitrogen  Phosphorus  Potassium   ph  Rainfall  Temperature       Crop
# 0           75          50        100  6.5      1000           20  Sugarcane
# 1           80          50        100  6.5      1000           20  Sugarcane
# 2           85          50        100  6.5      1000           20  Sugarcane
# 3           90          50        100  6.5      1000           20  Sugarcane
# 4           95          50        100  6.5      1000           20  Sugarcane
# ...        ...         ...        ...  ...       ...          ...        ...
# 4508       130          80        150  7.0      1400           30  Sugarcane
# 4509       135          80        150  7.0      1400           30  Sugarcane
# 4510       140          80        150  7.0      1400           30  Sugarcane
# 4511       145          80        150  7.0      1400           30  Sugarcane
# 4512       150          80        150  7.0      1400           30  Sugarcane
#
# [4513 rows x 7 columns]

# %%
df2
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature        ph    Rainfall  \
# 0           90          42         43    20.879744  6.502985  202.935536
# 1           85          58         41    21.770462  7.038096  226.655537
# 2           60          55         44    23.004459  7.840207  263.964248
# 3           74          35         40    26.491096  6.980401  242.864034
# 4           78          42         42    20.130175  7.628473  262.717340
# ...        ...         ...        ...          ...       ...         ...
# 2195       107          34         32    26.774637  6.780064  177.774507
# 2196        99          15         27    27.417112  6.086922  127.924610
# 2197       118          33         30    24.131797  6.362608  173.322839
# 2198       117          32         34    26.272418  6.758793  127.175293
# 2199       104          18         30    23.603016  6.779833  140.937041
#
#         Crop
# 0       rice
# 1       rice
# 2       rice
# 3       rice
# 4       rice
# ...

# %%
df=pd.concat([df1,df2])
df
# Out:
#       Nitrogen  Phosphorus  Potassium        ph     Rainfall  Temperature  \
# 0           75          50        100  6.500000  1000.000000    20.000000
# 1           80          50        100  6.500000  1000.000000    20.000000
# 2           85          50        100  6.500000  1000.000000    20.000000
# 3           90          50        100  6.500000  1000.000000    20.000000
# 4           95          50        100  6.500000  1000.000000    20.000000
# ...        ...         ...        ...       ...          ...          ...
# 2195       107          34         32  6.780064   177.774507    26.774637
# 2196        99          15         27  6.086922   127.924610    27.417112
# 2197       118          33         30  6.362608   173.322839    24.131797
# 2198       117          32         34  6.758793   127.175293    26.272418
# 2199       104          18         30  6.779833   140.937041    23.603016
#
#            Crop
# 0     Sugarcane
# 1     Sugarcane
# 2     Sugarcane
# ...

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium        ph     Rainfall  Temperature  \
# 0           75          50        100  6.500000  1000.000000    20.000000
# 1           80          50        100  6.500000  1000.000000    20.000000
# 2           85          50        100  6.500000  1000.000000    20.000000
# 3           90          50        100  6.500000  1000.000000    20.000000
# 4           95          50        100  6.500000  1000.000000    20.000000
# ...        ...         ...        ...       ...          ...          ...
# 2195       107          34         32  6.780064   177.774507    26.774637
# 2196        99          15         27  6.086922   127.924610    27.417112
# 2197       118          33         30  6.362608   173.322839    24.131797
# 2198       117          32         34  6.758793   127.175293    26.272418
# 2199       104          18         30  6.779833   140.937041    23.603016
#
#            Crop
# 0     Sugarcane
# 1     Sugarcane
# 2     Sugarcane
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6713 entries, 0 to 2199
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nitrogen     6713 non-null   int64
#  1   Phosphorus   6713 non-null   int64
#  2   Potassium    6713 non-null   int64
#  3   ph           6713 non-null   float64
#  4   Rainfall     6713 non-null   float64
#  5   Temperature  6713 non-null   float64
#  6   Crop         6713 non-null   object
# dtypes: float64(3), int64(3), object(1)
# memory usage: 419.6+ KB

# %%
x=df.drop(columns=['Crop'])
y=df['Crop']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=24)

# %%
model=RandomForestClassifier(
    n_estimators=50,
    max_features=0.5,
    bootstrap=True,
    criterion='gini',
    random_state=24,
    n_jobs=-1
)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_features=0.5, n_estimators=50, n_jobs=-1,
#                        random_state=24)

# %%
y_pred=model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9873417721518988

# %%
from joblib import dump


dump(model, 'crop_recommendation.joblib')
# Out:
# ['crop_recommendation.joblib']

# %%
with open('crop_recommendation.pkl','wb') as file:
  pickle.dump(model,file)
