# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
df_fer=pd.read_csv('/content/fertilizer complet dataset final.csv')
df_fer.drop_duplicates()
# Out:
#       Temperature Soil_color         Crop  Nitrogen  Phosphorus  Potassium  \
# 0              20      Black    Sugarcane        75          50        100
# 1              20      Black    Sugarcane        80          50        100
# 2              20      Black    Sugarcane        85          50        100
# 3              20      Black    Sugarcane        90          50        100
# 4              20      Black    Sugarcane        95          50        100
# ...           ...        ...          ...       ...         ...        ...
# 4646           28      Sandy       Barley         5          18         15
# 4647           24      Sandy       orange        22          17          5
# 4648           23      Sandy       orange         4          23          5
# 4649           12      Sandy       orange        11          14          5
# 4650           27     Clayey  kidneybeans        19          21          6
#
#       Fertilizer
# 0           Urea
# 1           Urea
# ...

# %%
x_1=df_fer.drop(columns=['Fertilizer'])
y_1=df_fer['Fertilizer']
y_1=pd.DataFrame(y_1)

# %%
columns_to_encode = ['Soil_color','Crop']
encoder = OneHotEncoder(drop='first', sparse_output=False) # Set sparse_output to False
encoded_data = encoder.fit_transform(x_1[columns_to_encode])
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(columns_to_encode))
x_1 = pd.concat([x_1.drop(columns_to_encode, axis=1), encoded_df], axis=1)

# %%
# ipython-input-14-8e0c0153f820
columns_to_encode = ['Fertilizer']
# Replace 'sparse' with 'sparse_output'
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_data = encoder.fit_transform(y_1[columns_to_encode])
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(columns_to_encode))
y_1 = pd.concat([y_1.drop(columns_to_encode, axis=1), encoded_df], axis=1)

# %%
x_train_1, x_test_1, y_train_1, y_test_1 = train_test_split(x_1, y_1, test_size=0.2, random_state=24)

# %%
model2 = RandomForestClassifier(
    n_estimators=200,
    random_state=24,
    n_jobs=-1,
    max_features=0.98,


)

# %%
model2.fit(x_train_1,y_train_1)
y_pred_2=model2.predict(x_test_1)
accuracy2=accuracy_score(y_test_1,y_pred_2)
print(accuracy2)
# Out:
# 0.9180651530108588

# %%
import pickle
filename = 'Fertilizer_model2.pkl'
pickle.dump(model2, open(filename, 'wb'))

# %%
# prompt: combine all the codel

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
import pickle

df_fer=pd.read_csv('/content/fertilizer complet dataset final.csv')
df_fer.drop_duplicates()
x_1=df_fer.drop(columns=['Fertilizer'])
y_1=df_fer['Fertilizer']
y_1=pd.DataFrame(y_1)

columns_to_encode = ['Soil_color','Crop']
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_data = encoder.fit_transform(x_1[columns_to_encode])
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(columns_to_encode))
x_1 = pd.concat([x_1.drop(columns_to_encode, axis=1), encoded_df], axis=1)

columns_to_encode = ['Fertilizer']
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_data = encoder.fit_transform(y_1[columns_to_encode])
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(columns_to_encode))
y_1 = pd.concat([y_1.drop(columns_to_encode, axis=1), encoded_df], axis=1)

x_train_1, x_test_1, y_train_1, y_test_1 = train_test_split(x_1, y_1, test_size=0.2, random_state=24)

model2 = RandomForestClassifier(
    n_estimators=200,
    random_state=24,
    n_jobs=-1,
    max_features=0.98,
)
model2.fit(x_train_1,y_train_1)
y_pred_2=model2.predict(x_test_1)
accuracy2=accuracy_score(y_test_1,y_pred_2)
print(accuracy2)

filename = 'Fertilizer_model2.pkl'
pickle.dump(model2, open(filename, 'wb'))
